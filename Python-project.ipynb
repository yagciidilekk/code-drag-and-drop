# %% [markdown]
# <a href="https://colab.research.google.com/github/yagciidilekk/code-drag-and-drop/blob/main/Python-project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
def tas_kagit_makas_DILEK_YAGCI():

    def oyun_hikayesi():
     print("Bir gün Amerika'ya taşınan müslüman baş örtülü bir kız çocuğu, sokakta oynarken taş, kağıt, makas oynamaya karar verdi.")
     print("Müslüman baş örtülü kız çocuğu, sokakta karşısına çıkan akranı yahudi kız çocuğu ile mücadele ediyor.")
     print("İlk başta, iki kız çocuğu da birbirlerine karşı temkinliydiler. Ancak oyun ilerledikçe, gülüşmeler ve neşeli sesler yükselmeye başladı.")
     print("Gözlerinin içi parlayan iki kız çocuğu da, kendi kültürlerinin hikayelerini paylaşarak birbirlerini daha iyi tanımaya başladılar.")
     print("Oyun sırasında, müslüman kız çocuğu, baş örtüsünün ne anlama geldiğini ve onun için ne kadar önemli olduğunu anlattı.")
     print("Yahudi kız çocuğu da, kendi geleneklerini ve özel günlerini paylaşarak, farklılıkların aslında ne kadar güzel olduğunu gösterdi.")
     print("Oyun sona erdiğinde her ikisi de kazananın kim olduğunu umursamıyordu; çünkü en büyük kazanç insanlığın bir çok sorunu varken günümüzde hala bu güzel farklılıkları kavrayamama hastalığına rağmen bu iki kız çocuğu yeni bir dostluk kurmuştu.")
     print("Artık birbirlerinin kültürlerine daha fazla saygı duyarak anlıyor ve daha fazla oyun oynamak için sözleşiyorlardı.")
     print("Bu dostluk, sokakta başlayan bir oyunla başlamıştı fakat kızların kalplerinde köklü bir bağ oluşturmuştu.")

def kullanici_secimi():

    while True:
        secim = input("Taş, Kağıt, veya Makas seçin (çıkmak için 'çık' yazın):").lower()
if secim in ['taş', 'kağıt', 'makas']:
            return secim
    elif secim == 'çık':
        print("Oyun sona erdi. Teşekkürler!")
        exit()

    else:
        print("Geçersiz seçim. Lütfen tekrar deneyin.")

def bilgisayar_secimi():
    return random.choice(['taş', 'kağıt', 'makas'])

def tur_sonuclarini_belirle(kullanici,bilgisayar):
    if kullanici == bilgisayar:
    return "Beraberlik!"
    elif(kullanici == 'taş' and bilgisayar == 'makas') or \
        (kullanici == 'kağıt' and bilgisayar == 'taş') or \
        (kullanici == 'makas' and bilgisayar == 'kağıt'):
    return "Kullanıcı kazandı!"

    else:
    return "Bilgisayar kazandı!"

def oyun():
    oyun_hikayesi()
    kullanici_galibiyetleri = 0
    bilgisayar_galibiyetleri = 0

    while kullanici_galibiyetleri < 2 and bilgisayar_galibiyetleri < 2:
    print("Yeni tur başlıyor!")
    kullanici = kullanici_secimi()
    bilgisayar = bilgisayar_secimi()
    print(f"Bilgisayarın seçimi:{bilgisayar}")
    sonuc = tur_sonuclarini_belirle(kullanici, bilgisayar)
    print(sonuc)
    if sonuc == "Kullanıcı kazandı!":
    kullanici_galibiyetleri += 1
    elif sonuc == "Bilgisayar kazandı!":
    bilgisayar_galibiyetleri += 1
    print(f"Kullanıcı Galibiyetleri: {kullanici_galibiyetleri}, Bilgisayar Galibiyetleri: {bilgisayar_galibiyetleri}")
    print()
    if kullanici_galibiyetleri == 2:
    print("Tebrikler! Oyunu kazandınız!")
    else:
    print("Üzgünüm, bilgisayar galip geldi!")
    if _ name _ == "_main_":
    oyun()import random
def tas_kagit_makas_DILEK_YAGCI():

    def oyun_hikayesi():
     print("Bir gün Amerika'ya taşınan müslüman baş örtülü bir kız çocuğu, sokakta oynarken taş, kağıt, makas oynamaya karar verdi.")
     print("Müslüman baş örtülü kız çocuğu, sokakta karşısına çıkan akranı yahudi kız çocuğu ile mücadele ediyor.")
     print("İlk başta, iki kız çocuğu da birbirlerine karşı temkinliydiler. Ancak oyun ilerledikçe, gülüşmeler ve neşeli sesler yükselmeye başladı.")
     print("Gözlerinin içi parlayan iki kız çocuğu da, kendi kültürlerinin hikayelerini paylaşarak birbirlerini daha iyi tanımaya başladılar.")
     print("Oyun sırasında, müslüman kız çocuğu, baş örtüsünün ne anlama geldiğini ve onun için ne kadar önemli olduğunu anlattı.")
     print("Yahudi kız çocuğu da, kendi geleneklerini ve özel günlerini paylaşarak, farklılıkların aslında ne kadar güzel olduğunu gösterdi.")
     print("Oyun sona erdiğinde her ikisi de kazananın kim olduğunu umursamıyordu; çünkü en büyük kazanç insanlığın bir çok sorunu varken günümüzde hala bu güzel farklılıkları kavrayamama hastalığına rağmen bu iki kız çocuğu yeni bir dostluk kurmuştu.")
     print("Artık birbirlerinin kültürlerine daha fazla saygı duyarak anlıyor ve daha fazla oyun oynamak için sözleşiyorlardı.")
     print("Bu dostluk, sokakta başlayan bir oyunla başlamıştı fakat kızların kalplerinde köklü bir bağ oluşturmuştu.")

def kullanici_secimi():

    while True:
        secim = input("Taş, Kağıt, veya Makas seçin (çıkmak için 'çık' yazın):").lower()
if secim in ['taş', 'kağıt', 'makas']:
            return secim
    elif secim == 'çık':
        print("Oyun sona erdi. Teşekkürler!")
        exit()

    else:
        print("Geçersiz seçim. Lütfen tekrar deneyin.")

def bilgisayar_secimi():
    return random.choice(['taş', 'kağıt', 'makas'])

def tur_sonuclarini_belirle(kullanici,bilgisayar):
    if kullanici == bilgisayar:
    return "Beraberlik!"
    elif(kullanici == 'taş' and bilgisayar == 'makas') or \
        (kullanici == 'kağıt' and bilgisayar == 'taş') or \
        (kullanici == 'makas' and bilgisayar == 'kağıt'):
    return "Kullanıcı kazandı!"

    else:
    return "Bilgisayar kazandı!"

def oyun():
    oyun_hikayesi()
    kullanici_galibiyetleri = 0
    bilgisayar_galibiyetleri = 0

    while kullanici_galibiyetleri < 2 and bilgisayar_galibiyetleri < 2:
    print("Yeni tur başlıyor!")
    kullanici = kullanici_secimi()
    bilgisayar = bilgisayar_secimi()
    print(f"Bilgisayarın seçimi:{bilgisayar}")
    sonuc = tur_sonuclarini_belirle(kullanici, bilgisayar)
    print(sonuc)
    if sonuc == "Kullanıcı kazandı!":
    kullanici_galibiyetleri += 1
    elif sonuc == "Bilgisayar kazandı!":
    bilgisayar_galibiyetleri += 1
    print(f"Kullanıcı Galibiyetleri: {kullanici_galibiyetleri}, Bilgisayar Galibiyetleri: {bilgisayar_galibiyetleri}")
    print()
    if kullanici_galibiyetleri == 2:
    print("Tebrikler! Oyunu kazandınız!")
    else:
    print("Üzgünüm, bilgisayar galip geldi!")
    if _ name _ == "_main_":
    oyun()
# Out:
#   File "<tokenize>", line 21
#     elif secim == 'çık':
#     ^
# IndentationError: unindent does not match any outer indentation level
